# %% [markdown]
# # Tiesinė regresija atsakymas 2

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
wines = pd.read_csv('https://raw.githubusercontent.com/robotautas/kursas/master/Machine%20Learning/winequality-red.csv')
